# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\yp_smart pc\anaconda3\lib\site-packages (4.5.1.48)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\yp_smart pc\anaconda3\lib\site-packages (from opencv-python) (1.19.2)

# %%
import cv2

# %%
img=cv2.imread('C:/Users/YP_Smart PC/Pictures/battlefront.jpg')
img.shape
# Out:
# (139, 378, 3)

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('C:/Users/YP_Smart PC/Pictures/battlefront.jpg',0)

hist,bins = np.histogram(img.flatten(),256,[0,256])

cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()

# %%
plt.imshow(img)

# %%
plt.plot(cdf_normalized, color = 'b')
plt.hist(img.flatten(),256,[0,256], color = 'g')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %%
img2 = cdf[img]
plt.plot(cdf_normalized, color = 'b')
plt.hist(img2.flatten(),256,[0,256], color = 'g')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %%
plt.imshow(img2)
